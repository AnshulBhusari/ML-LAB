# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
X = np.array([[1],[2],[3],[4],[5]])
y =np.array([[20],[40],[50],[65],[80]])

# %%
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)

# %%
plt.scatter(X,y,color='green',label="Actual Data")
plt.plot(X,y_pred,color='red',label="Regression Line",linewidth=2)
plt.legend()
plt.xlabel("Hours studied")
plt.ylabel("Test Score")
plt.show()

# %%
mae = mean_absolute_error(y, y_pred)
mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mse)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
# Out:
# Mean Absolute Error: 1.3999999999999992
# Mean Squared Error: 3.5000000000000013
# Root Mean Squared Error: 1.870828693386971
